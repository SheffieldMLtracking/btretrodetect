# %%
from btretrodetect import Retrodetect, ColourRetrodetect
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import pickle

#TODO: Move the demo images to the btdatasets repo
#btdatasets_folder = '../../btdatasets/'

# !echo '{"camid": [26,50]}' > /home/mike/.btretrodetect/offset.json

g_fns = sorted(glob('/home/mike/Documents/Research/beephotos/2025-04-18/flat_tag_7m/121_leegreen/1040/M-DA3120198/*.np'))
c_fns = sorted(glob('/home/mike/Documents/Research/beephotos/2025-04-18/flat_tag_7m/121_leegreen/1040/C-DA3075133/*.np'))

g_rd = Retrodetect(base_path='.')
c_rd = ColourRetrodetect(patchSize=48,base_path='.')
g_rd.associated_colour_retrodetect = c_rd
# Out:
# Using /home/mike/.btretrodetect/offset.json offset file (26, 50)

# %%
for i,(g_fn,c_fn) in enumerate(zip(g_fns[0:20],c_fns[0:20])):
    g_photo = pickle.load(open(g_fn,'rb'))
    c_photo = pickle.load(open(c_fn,'rb'))
    g_rd.process_image(g_photo) 
    c_rd.process_image(c_photo)
# Out:
# uint8
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+53.419560_0253.np
# ===================
#    175.79 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.175867
# MATCH: 20250418_11+20+53.419560_0253.np=20250418_11+20+53.419560_0253.np
# No patches
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+53.419560_0253.np
# ===================
# TOTAL TIME [colour image] 0.242434
# uint8
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+54.429430_0254.np
# ===================
#     55.24 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.055302
# MATCH: 20250418_11+20+54.429430_0254.np=20250418_11+20+54.429430_0254.np
# No patches
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+54.429430_0254.np
# ===================
# TOTAL TIME [colour image] 0.126614
# uint8
# 202 152
# 274 251
# 74 28
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+55.436697_0255.np
# ===================
#     64.22 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.064272
# MATCH: 20250418_11+20+55.436697_0255.np=20250418_11+20+55.436697_0255.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+55.436697_0255.np
# ===================
# TOTAL TIME [colour image] 0.136698
# uint8
# 201 154
# 74 28
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+56.443311_0256.np
# ===================
#     64.68 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.064755
# MATCH: 20250418_11+20+56.443311_0256.np=20250418_11+20+56.443311_0256.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+56.443311_0256.np
# ===================
# TOTAL TIME [colour image] 0.126937
# uint8
# 200 155
# 193 202
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+57.450327_0257.np
# ===================
#     65.20 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.065273
# MATCH: 20250418_11+20+57.450327_0257.np=20250418_11+20+57.450327_0257.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+57.450327_0257.np
# ===================
# TOTAL TIME [colour image] 0.127211
# uint8
# 194 143
# 79 285
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+58.457948_0258.np
# ===================
#     62.40 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.06248
# MATCH: 20250418_11+20+58.457948_0258.np=20250418_11+20+58.457948_0258.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+58.457948_0258.np
# ===================
# TOTAL TIME [colour image] 0.16675
# uint8
# 204 155
# 234 124
# 382 98
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+20+59.465331_0259.np
# ===================
#     62.57 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.062628
# MATCH: 20250418_11+20+59.465331_0259.np=20250418_11+20+59.465331_0259.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+20+59.465331_0259.np
# ===================
# TOTAL TIME [colour image] 0.24503
# uint8
# 196 109
# 250 97
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+00.472721_0260.np
# ===================
#     60.90 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.060966
# MATCH: 20250418_11+21+00.472721_0260.np=20250418_11+21+00.472721_0260.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+00.472721_0260.np
# ===================
# TOTAL TIME [colour image] 0.207373
# uint8
# 185 163
# 260 211
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+01.489012_0261.np
# ===================
#     60.41 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.06047
# MATCH: 20250418_11+21+01.489012_0261.np=20250418_11+21+01.489012_0261.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+01.489012_0261.np
# ===================
# TOTAL TIME [colour image] 0.209251
# uint8
# 190 132
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+02.497256_0262.np
# ===================
#     64.05 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.064109
# MATCH: 20250418_11+21+02.497256_0262.np=20250418_11+21+02.497256_0262.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+02.497256_0262.np
# ===================
# TOTAL TIME [colour image] 0.216126
# uint8
# 170 163
# 200 126
# 78 146
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+03.512118_0263.np
# ===================
#     63.32 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.063386
# MATCH: 20250418_11+21+03.512118_0263.np=20250418_11+21+03.512118_0263.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+03.512118_0263.np
# ===================
# TOTAL TIME [colour image] 0.204155
# uint8
# 141 141
# 237 189
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+04.526016_0264.np
# ===================
#     58.11 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.05817
# MATCH: 20250418_11+21+04.526016_0264.np=20250418_11+21+04.526016_0264.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+04.526016_0264.np
# ===================
# TOTAL TIME [colour image] 0.20651
# uint8
# 130 122
# 176 125
# 230 157
# 159 103
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+05.541264_0265.np
# ===================
#     59.52 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.059595
# MATCH: 20250418_11+21+05.541264_0265.np=20250418_11+21+05.541264_0265.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+05.541264_0265.np
# ===================
# TOTAL TIME [colour image] 0.216279
# uint8
# 117 161
# 230 157
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+06.550671_0266.np
# ===================
#     68.23 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.068337
# MATCH: 20250418_11+21+06.550671_0266.np=20250418_11+21+06.550671_0266.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+06.550671_0266.np
# ===================
# TOTAL TIME [colour image] 0.220306
# uint8
# 96 160
# 303 242
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+07.561408_0267.np
# ===================
#     58.93 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.058981
# MATCH: 20250418_11+21+07.561408_0267.np=20250418_11+21+07.561408_0267.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+07.561408_0267.np
# ===================
# TOTAL TIME [colour image] 0.20085
# uint8
# 77 143
# 230 157
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+08.576894_0268.np
# ===================
#     59.78 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.059838
# MATCH: 20250418_11+21+08.576894_0268.np=20250418_11+21+08.576894_0268.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+08.576894_0268.np
# ===================
# TOTAL TIME [colour image] 0.210945
# uint8
# 54 130
# 262 12
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+09.592033_0269.np
# ===================
#     73.26 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.07333
# MATCH: 20250418_11+21+09.592033_0269.np=20250418_11+21+09.592033_0269.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+09.592033_0269.np
# ===================
# TOTAL TIME [colour image] 0.224051
# uint8
# 25 145
# 72 129
# 148 165
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+10.629866_0270.np
# ===================
#     69.78 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.069858
# MATCH: 20250418_11+21+10.629866_0270.np=20250418_11+21+10.629866_0270.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+10.629866_0270.np
# ===================
# TOTAL TIME [colour image] 0.238099
# uint8
# 19 135
# 66 129
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+11.658432_0271.np
# ===================
#     64.15 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.064213
# MATCH: 20250418_11+21+11.658432_0271.np=20250418_11+21+11.658432_0271.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+11.658432_0271.np
# ===================
# TOTAL TIME [colour image] 0.188952
# uint8
# 33 184
# 327 175
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/M-DA3120198/compact_20250418_11+21+12.689112_0272.np
# ===================
#     65.03 ms, TOTAL
# TOTAL TIME TAG FINDING [greyscale]:  0.065117
# MATCH: 20250418_11+21+12.689112_0272.np=20250418_11+21+12.689112_0272.np
# ===================
# ./2025-05-28/flat_tag_7m_compact/121_leegreen_compact/1040/C-DA3075133/compact_20250418_11+21+12.689112_0272.np
# ===================
# TOTAL TIME [colour image] 0.153813

# %%
print("Waiting for photos...")
greyscale_index,greyscale_photoitem = self.greyscale_photo_queue.pop()
print(" greyscale popped ")
self.           
colour_index,colour_photoitem = self.colour_photo_queue.pop()
print(" colour popped  --> processing.")
self.c_rd.process_image(colour_photoitem)

# %% [markdown]
# ===

# %%
from btretrodetect import 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob
import pickle

#this demo needs the btdatasets repo (set location here)
btdatasets_folder = '../../btdatasets/'

fns = sorted(glob(btdatasets_folder+'realbee_2023-06-29/sessionA/setA/cam4/02G14695548/photo_object_02G14695548_20230629_10:32*.np'))

rd = Retrodetect()
for i,fn in enumerate(fns[0:20]):
    res = rd.process_photo(pickle.load(open(fn,'rb')))
    if (i>6):
        #print(i,fn)
        for j,r in enumerate(res):
            #print(r)
            if r[0]>0:
                plt.figure(figsize=[20,10])
                #plt.subplot(5,2,j*2+1)
                plt.subplot(1,2,1)
                plt.imshow(r[-2])#diff
                plt.colorbar()
                plt.title(fn[-10:]+"%0.1f:(%0.1f,%0.1f) %0.1f,%0.1f,%0.1f,%0.1f,%0.1f,%0.1f" % tuple(r[:-2]))
                #plt.subplot(5,2,j*2+2)
                plt.subplot(1,2,2)
                plt.imshow(r[-1])
                plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from retrodetect import Retrodetect
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'retrodetect'
